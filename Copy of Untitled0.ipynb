# %%
import pandas as pd
import numpy as np

# %%
info=np.array(['p','y','t','h','o','n'])
a = pd.Series(info)
print(a)
# Out:
# 0    p
# 1    y
# 2    t
# 3    h
# 4    o
# 5    n
# dtype: object

# %%
import pandas as pd
x = ['python','language']
df = pd.DataFrame(x)
print(df)
# Out:
#           0
# 0    python
# 1  language

# %%
import pandas as pd
import numpy as np
a = pd.Series(['c++','java','c',np.nan])
a.map({'c++':'core'})
# Out:
# 0    core
# 1     NaN
# 2     NaN
# 3     NaN
# dtype: object

# %%
import pandas as pd
import numpy as np
a = pd.Series(['c++','java','c',np.nan])
a.map({'c++':'core'})
a.map('I like {}'.format, na_action='ignore')
# Out:
# 0     I like c++
# 1    I like java
# 2       I like c
# 3            NaN
# dtype: object

# %%
s = pd.Series(["x","y","z"],
name="vals")
s.to_frame()
# Out:
#   vals
# 0    x
# 1    y
# 2    z

# %%
import pandas as pd
import matplotlib.pyplot as plt
emp = ['gracy','jack','george']
id = [108, 106, 119]
emp_series = pd.Series(emp)
id_series = pd.Series(id)
frame = {'Emp':emp_series, 'ID':id_series}
result = pd.DataFrame(frame)
print(result)
# Out:
#       Emp   ID
# 0   gracy  108
# 1    jack  106
# 2  george  119

# %%
import pandas as pd
df = pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd
z = ['anaconda','jupiter']
df = pd.DataFrame(z)
print(df)
# Out:
#           0
# 0  anaconda
# 1   jupiter

# %%
import pandas as pd
info = {'roll no':[201, 202, 203],'department':['BBA','BCA','MCA',]}
df = pd.DataFrame(info)
print(df)
# Out:
#    roll no department
# 0      201        BBA
# 1      202        BCA
# 2      203        MCA

# %%
import pandas as pd
info = {'first':pd.Series([1,2,3,4,5,6,7], index=['a','b','c','d','e','f','g']),
'second':pd.Series([1,2,3,4,5,6,7,8,9], index=['a','b','c','d','e','f','g','h','i'])}
d1 = pd.DataFrame(info)
print(d1)
# Out:
#    first  second
# a    1.0       1
# b    2.0       2
# c    3.0       3
# d    4.0       4
# e    5.0       5
# f    6.0       6
# g    7.0       7
# h    NaN       8
# i    NaN       9
